# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn import datasets,linear_model
from sklearn.metrics import mean_squared_error

diabetes=datasets.load_diabetes()

print(diabetes.keys())

print(diabetes.DESCR)

d_X=diabetes.data[:,np.newaxis,2]

d_X_train=d_X[:-30]

d_X_test=d_X[-30:]

d_Y_train=diabetes.target[:-30]

d_Y_test=diabetes.target[-30:]

model=linear_model.LinearRegression()

model.fit(d_X_train,d_Y_train)

d_Y_pred=model.predict(d_X_test)

print("Mean Square Error:",mean_squared_error(d_X_test,d_Y_pred))

print("Coeff:",model.coef_)

print("Intercept:",model.intercept_)

plt.scatter(d_X_test,d_Y_test)

plt.plot(d_X_test,d_Y_pred)

plt.show()
# Out:
# dict_keys(['data', 'target', 'frame', 'DESCR', 'feature_names', 'data_filename', 'target_filename', 'data_module'])
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
#   :Number of Instances: 442
#
#   :Number of Attributes: First 10 columns are numeric predictive values
#
#   :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
#   :Attribute Information:
#       - age     age in years
#       - sex
#       - bmi     body mass index
#       - bp      average blood pressure
#       - s1      tc, total serum cholesterol
#       - s2      ldl, low-density lipoproteins
#       - s3      hdl, high-density lipoproteins
# ...

# %%
boston=datasets.load_boston(return_X_y=False)

X=boston.data
y=boston.target

from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test=train_test_split(X,y,test_size=0.4,random_state=1)

reg=linear_model.LinearRegression()

reg.fit(X_train,Y_train)

print("Coeff:",reg.coef_)

print("Variance:",reg.score(X_test,Y_test))

plt.style.use('fivethirtyeight')

plt.scatter(reg.predict(X_train),reg.predict(X_train)-Y_train,color="green",s=10,label='Train data')

plt.scatter(reg.predict(X_test),reg.predict(X_test)-Y_test,color="Blue",s=10,label='Test data')

plt.hlines(y=0,xmin=0,xmax=50)

plt.legend(loc="upper right")

plt.title("Residual errors")

plt.show()
# Out:
# Coeff: [-8.95714048e-02  6.73132853e-02  5.04649248e-02  2.18579583e+00
#  -1.72053975e+01  3.63606995e+00  2.05579939e-03 -1.36602886e+00
#   2.89576718e-01 -1.22700072e-02 -8.34881849e-01  9.40360790e-03
#  -5.04008320e-01]
# Variance: 0.7209056672661758
# C:\Users\merly\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
# ...

# %%
import numpy as np
import pandas as pd
df=pd.read_csv(r"C:\Users\merly\Downloads\d.csv")
#univariant analysis

print(df.head())
print(df.tail())
print(df.shape)
print(df.info())
print(df.describe())
print(df.var())
print(df.median())
print(df.mean())
print(df.mode())
print(df.skew(axis=0))
print(df.kurtosis(axis=0))
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
# (768, 9)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv(r"C:\Users\merly\Downloads\heart2.csv")

#correlation plot

#1.Pairplot

sns.pairplot(data=df)

plt.title("Pairplot")

#2.Heatmap

plt.figure(figsize=(20,10))

sns.heatmap(df.corr(),annot=True,cmap="terrain")

plt.title("Heatmap")

plt.show()

# %%
#scatter plot

f,ax=plt.subplots(figsize=(8,6))
ax=sns.scatterplot(x='age',y='resting_blood_pressure',data=df)
plt.title("Scatter Plot")
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

fig=plt.figure()
df=pd.read_csv(r"C:\Users\merly\Downloads\heart2.csv")

ax=plt.axes(projection="3d")

x=df["age"]
x=pd.Series(x,name="Age Variable")

z=df["serum_cholestoral"]
z=pd.Series(z,name="Cholestral Variable")
y=df["slope"]
y=pd.Series(y,name="Slope Variable")
ax.plot3D(x,y,z,'green')
ax.set_title("3D")

plt.show()

# %%
#density plot

f,ax=plt.subplots(figsize=(10,6))
x=df['age']
x=pd.Series(x,name="Age Variable")
ax=sns.kdeplot(x,shade=True,color='r')
plt.show()

# %%
# Implementation of matplotlib function
import matplotlib.pyplot as plt
import numpy as np

feature_x = np.linspace(-5.0, 3.0, 70)
feature_y = np.linspace(-5.0, 3.0, 70)

# Creating 2-D grid of features
[X, Y] = np.meshgrid(feature_x, feature_y)

fig, ax = plt.subplots(1, 1)

Z = X ** 2 + Y ** 2

# plots filled contour plot
ax.contourf(X, Y, Z)

ax.set_title('Filled Contour Plot')
ax.set_xlabel('feature_x')
ax.set_ylabel('feature_y')

plt.show()

# %%
df.hist(figsize=(12,12),layout=(5,3))
plt.show()

# %%
import scipy.stats as stats
mean=np.mean(df['age'])
sd=np.std(df['age'])
p=stats.norm.pdf(df['age'].sort_values(),mean,sd)
plt.plot(df['age'].sort_values(),p)
plt.show()

# %%
df=pd.read_csv(r"C:\Users\merly\Downloads\iris.csv")
df.value_counts("class")
# Out:
# class
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
df.hist(figsize=(12,12),layout=(1,4))
plt.show()

# %%
import matplotlib.pyplot as plt
x=[2,4,1,8,3]
y=[31,12,70,44,26]
x.sort()
y.sort()
plt.hist(x)
plt.hist(y)
plt.show()

plt.plot(x,y)
plt.show()

plt.scatter(x,y)
plt.show()

plt.bar(x,y)
plt.show()

sns.countplot(x='class',data=df)
plt.show()

sns.scatterplot(x='sepallength',y='sepalwidth',hue="class",data=df)
plt.legend(bbox_to_anchor=(1,1),loc=2)

# %%
sns.pairplot(data=df,hue="class")
plt.show()

# %%
df=pd.read_fwf(r"C:\Users\merly\OneDrive\Documents\menu.txt")
print(df)
# Out:
#   menu pricing
# 0      dosa 20
# 1  chappati 30
# 2  biriyani 50

# %%
df=pd.read_excel(r"C:\Users\merly\Downloads\Book1.xlsx")
print(df)
# Out:
#   name gender
# 0   ab      m
# 1   ac      f

# %%
url="https://en.wikipedia.org/wiki/History_of_Python"

df=pd.read_html(url)

print(df)
# Out:
# [                                              Version  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# ...
