# %%
import numpy as np
l1=[1,2,3,4]
sa=np.array(l1)
print("List:",l1)
print("Array:",sa)
# Out:
# List: [1, 2, 3, 4]
# Array: [1 2 3 4]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv(r"C:\\Users\\merly\\Downloads\\heart2.csv")
df.head()
# Out:
#    age  sex  chest  resting_blood_pressure  serum_cholestoral  \
# 0   70    1      4                     130                322
# 1   67    0      3                     115                564
# 2   57    1      2                     124                261
# 3   64    1      4                     128                263
# 4   74    0      2                     120                269
#
#    fasting_blood_sugar  resting_electrocardiographic_results  \
# 0                    0                                     2
# 1                    0                                     2
# 2                    0                                     0
# 3                    0                                     0
# 4                    0                                     2
#
#    maximum_heart_rate_achieved  exercise_induced_angina  oldpeak  slope  \
# 0                          109                        0      2.4      2
# 1                          160                        0      1.6      2
# ...

# %%
df=pd.read_csv(r"C:\\Users\\merly\\Downloads\\heart2.csv")
df.tail()
# Out:
#      age  sex  chest  resting_blood_pressure  serum_cholestoral  \
# 265   52    1      3                     172                199
# 266   44    1      2                     120                263
# 267   56    0      2                     140                294
# 268   57    1      4                     140                192
# 269   67    1      4                     160                286
#
#      fasting_blood_sugar  resting_electrocardiographic_results  \
# 265                    1                                     0
# 266                    0                                     0
# 267                    0                                     2
# 268                    0                                     0
# 269                    0                                     2
#
#      maximum_heart_rate_achieved  exercise_induced_angina  oldpeak  slope  \
# 265                          162                        0      0.5      1
# ...

# %%
df.shape
# Out:
# (270, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 14 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   age                                   270 non-null    int64
#  1   sex                                   270 non-null    int64
#  2   chest                                 270 non-null    int64
#  3   resting_blood_pressure                270 non-null    int64
#  4   serum_cholestoral                     270 non-null    int64
#  5   fasting_blood_sugar                   270 non-null    int64
#  6   resting_electrocardiographic_results  270 non-null    int64
#  7   maximum_heart_rate_achieved           270 non-null    int64
#  8   exercise_induced_angina               270 non-null    int64
#  9   oldpeak                               270 non-null    float64
#  10  slope                                 270 non-null    int64
# ...

# %%
df.describe()
# Out:
#               age         sex       chest  resting_blood_pressure  \
# count  270.000000  270.000000  270.000000              270.000000
# mean    54.433333    0.677778    3.174074              131.344444
# std      9.109067    0.468195    0.950090               17.861608
# min     29.000000    0.000000    1.000000               94.000000
# 25%     48.000000    0.000000    3.000000              120.000000
# 50%     55.000000    1.000000    3.000000              130.000000
# 75%     61.000000    1.000000    4.000000              140.000000
# max     77.000000    1.000000    4.000000              200.000000
#
#        serum_cholestoral  fasting_blood_sugar  \
# count         270.000000           270.000000
# mean          249.659259             0.148148
# std            51.686237             0.355906
# min           126.000000             0.000000
# 25%           213.000000             0.000000
# 50%           245.000000             0.000000
# ...

# %%
df.mode()
# Out:
#    age  sex  chest  resting_blood_pressure  serum_cholestoral  \
# 0   54    1      4                     120                234
#
#    fasting_blood_sugar  resting_electrocardiographic_results  \
# 0                    0                                     2
#
#    maximum_heart_rate_achieved  exercise_induced_angina  oldpeak  slope  \
# 0                          162                        0      0.0      1
#
#    number_of_major_vessels  thal   class
# 0                        0     3  absent

# %%
df.mode(axis=1)
# Out:
#        0    1    2   3
# 0    0.0  2.0  3.0 NaN
# 1    0.0  NaN  NaN NaN
# 2    0.0  NaN  NaN NaN
# 3    1.0  NaN  NaN NaN
# 4    1.0  NaN  NaN NaN
# ..   ...  ...  ...  ..
# 265  0.0  1.0  NaN NaN
# 266  0.0  NaN  NaN NaN
# 267  0.0  NaN  NaN NaN
# 268  0.0  NaN  NaN NaN
# 269  1.0  2.0  3.0 NaN
#
# [270 rows x 4 columns]

# %%
df.median()
# Out:
# C:\Users\merly\AppData\Local\Temp\ipykernel_35660\530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# age                                      55.0
# sex                                       1.0
# chest                                     3.0
# resting_blood_pressure                  130.0
# serum_cholestoral                       245.0
# fasting_blood_sugar                       0.0
# resting_electrocardiographic_results      2.0
# maximum_heart_rate_achieved             153.5
# exercise_induced_angina                   0.0
# oldpeak                                   0.8
# slope                                     2.0
# number_of_major_vessels                   0.0
# thal                                      3.0
# dtype: float64

# %%
df.var()
# Out:
# C:\Users\merly\AppData\Local\Temp\ipykernel_35660\1568254755.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.var()
# age                                       82.975093
# sex                                        0.219207
# chest                                      0.902671
# resting_blood_pressure                   319.037051
# serum_cholestoral                       2671.467107
# fasting_blood_sugar                        0.126669
# resting_electrocardiographic_results       0.995787
# maximum_heart_rate_achieved              536.650434
# exercise_induced_angina                    0.221795
# oldpeak                                    1.311506
# slope                                      0.377475
# number_of_major_vessels                    0.890940
# thal                                       3.766157
# ...

# %%
df.skew()
# Out:
# C:\Users\merly\AppData\Local\Temp\ipykernel_35660\1665899112.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.skew()
# age                                    -0.163615
# sex                                    -0.765084
# chest                                  -0.878767
# resting_blood_pressure                  0.722618
# serum_cholestoral                       1.183721
# fasting_blood_sugar                     1.991971
# resting_electrocardiographic_results   -0.044703
# maximum_heart_rate_achieved            -0.527737
# exercise_induced_angina                 0.728915
# oldpeak                                 1.262893
# slope                                   0.543151
# number_of_major_vessels                 1.209890
# thal                                    0.287268
# dtype: float64

# %%
df.kurt()
# Out:
# C:\Users\merly\AppData\Local\Temp\ipykernel_35660\1257127604.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.kurt()
# age                                    -0.544815
# sex                                    -1.425259
# chest                                  -0.296548
# resting_blood_pressure                  0.923097
# serum_cholestoral                       4.895599
# fasting_blood_sugar                     1.982578
# resting_electrocardiographic_results   -2.005358
# maximum_heart_rate_achieved            -0.103072
# exercise_induced_angina                -1.479699
# oldpeak                                 1.759317
# slope                                  -0.606572
# number_of_major_vessels                 0.298238
# thal                                   -1.900618
# dtype: float64

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
df.boxplot()
plt.xticks(rotation=90)
plt.show()

# %%
df.plot(kind='box',subplots=True,layout=(5,3),figsize=(12,12))
plt.show()

# %%
sns.heatmap(df.corr())
plt.show()

# %%
print(df.corr())
# Out:
#                                            age       sex     chest  \
# age                                   1.000000 -0.094401  0.096920
# sex                                  -0.094401  1.000000  0.034636
# chest                                 0.096920  0.034636  1.000000
# resting_blood_pressure                0.273053 -0.062693 -0.043196
# serum_cholestoral                     0.220056 -0.201647  0.090465
# fasting_blood_sugar                   0.123458  0.042140 -0.098537
# resting_electrocardiographic_results  0.128171  0.039253  0.074325
# maximum_heart_rate_achieved          -0.402215 -0.076101 -0.317682
# exercise_induced_angina               0.098297  0.180022  0.353160
# oldpeak                               0.194234  0.097412  0.167244
# slope                                 0.159774  0.050545  0.136900
# number_of_major_vessels               0.356081  0.086830  0.225890
# thal                                  0.106100  0.391046  0.262659
#
# ...

# %%
df.hist(figsize=(12,12),layout=(5,3))
plt.show()

# %%
sns.pairplot(data=df)
plt.show()

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(),annot=True,cmap='terrain')
plt.show()

# %%
f,a=plt.subplots(figsize=(8,6))
a=sns.countplot(x='age',data=df)
plt.show()

# %%
a=sns.countplot(x='number_of_major_vessels',data=df)
plt.show()

# %%
a=sns.countplot(x='class',data=df)
plt.show()
